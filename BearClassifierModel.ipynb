# %%
# !pip install ipywidgets
# !pip install fastai==2.8.4 --upgrade
# !pip install torch==2.8.0 torch!=2.8.0+cu126 --upgrade
# !pip install voila
# !jupyter server extension enable voila --sys-prefix
# !pip install -Uqq fastbook
# !pip install -U jupyterlab ipywidgets jupyterlab-widgets
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager

# %%
import fastai.vision.all as fastai
import ipywidgets as widgets
import traceback
import fastbook

# %%
black_bear_imgs = [
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%2Fid%2FOIP.m7z3d7W263Aptr_CGJKhVAHaFu%3Fpid%3DApi&f=1&ipt=252d7d8c204aa04af5fc1ef2ca0e44a56df701548535120e07cd9bac02eaa18e&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%2Fid%2FOIP.5aeHcTSSzXQPH8MVynwJrQHaHa%3Fpid%3DApi&f=1&ipt=4d70bda29e3e077d60709ca352b12199384e0e158d11f3f49329a0eea03fe2cc&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%2Fid%2FOIP.-Z2se3rMauFLWRTM-sNVHgHaFj%3Fpid%3DApi&f=1&ipt=b9c074b3df65e1a2fe4e7b2c502874b5957ef4fbb89f2df9a30eb26a77094d3f&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%2Fid%2FOIP.f1O1wmn5A8m_zqec2zLZAQAAAA%3Fpid%3DApi&f=1&ipt=3cfeb3061bc8bed456193d6c397e1e20a9b2a24064cf61d9eae4fc2c9e13f1cd&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%2Fid%2FOIP.YTIJBGjm-YjjDlAJz8dFewHaFl%3Fpid%3DApi&f=1&ipt=b3b30632518f34af6456ba33286950c964b1911b948784f32399474e4f58d00b&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%2Fid%2FOIP.r84wxwuPdVcMSN1Y4qDp_QHaFD%3Fpid%3DApi&f=1&ipt=a5ec5577a15932b31c3f9beea3e0eb82d21fbc4b92fb39229731f2f3fd0c8898&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%2Fid%2FOIP.ijJXvxVr6cv7wrEZjQbnhQHaHq%3Fpid%3DApi&f=1&ipt=bc7f5c75ce3155c09ee6c6e4e5dfb96399c079132ba0ff1fcf382d8ecd27046e&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%2Fid%2FOIP.iLQFvSmyCPthmABpI1gfkQHaFp%3Fpid%3DApi&f=1&ipt=2cc8c2fc52a8673de78022bd898bd4c4b0aea92c61cba870c8630cd548cfb8dd&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%2Fid%2FOIP.MRpx-RHYvaCyNxpeR22sQwHaE8%3Fpid%3DApi&f=1&ipt=24c42863fe1f55162ebf15c093523a61a9d99ea360304e58ddd0329ce7e9eda5&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%2Fid%2FOIP.aslQIwtqBOM7itVBpz0XDAHaFj%3Fpid%3DApi&f=1&ipt=c563c947f53acf853befb5ec7ed86773f7129f277a3c55d7e0bcd86c39d0c802&ipo=images',
]
grizzly_bear_imgs = [
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse4.mm.bing.net%2Fth%2Fid%2FOIP.8XArw0oc_2-dEI1In7CUCAHaE8%3Fpid%3DApi&f=1&ipt=7dbe5d362a156f606adda114494e7e0c0bd981a830906c334780bddcd1aa2c28&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse4.mm.bing.net%2Fth%2Fid%2FOIP.1qjVNM93gpWmEJHUZQVihAHaE8%3Fpid%3DApi&f=1&ipt=d71854a659f35464e845120aa375b43ffe823f562a5068e9230f8efdfed370d3&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%2Fid%2FOIP.N_SUoLFzw99Tu0n9yFlmFQHaHm%3Fpid%3DApi&f=1&ipt=5525c3a7f33c4a82cd5d3c9ad70dc533719b96d492fac5de38841e626c4fca11&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse4.mm.bing.net%2Fth
ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.explicit.bing.net%2Fth%2Fid%2FOIP.saIozeFFSx12-S8KiUbfZwHaJS%3Fr%3D0%26pid%3DApi&f=1&ipt=458eec75f9bc734588594824de9e8fb9d56f0909cc75d76b673e2106d1033572&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.mm.bing.net%2Fth%2Fid%2FOIP.ccGPA45Mf41H7P_eCd8NEAHaHa%3Fr%3D0%26pid%3DApi&f=1&ipt=4d1fc1025b6eb958014f0bacd43931f2cfb6591522a09a3cb9261cba742ef31a&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.explicit.bing.net%2Fth%2Fid%2FOIP.snzYbUdmrFZUp-jK7V6PgQHaJh%3Fr%3D0%26pid%3DApi&f=1&ipt=298d382b93d7692531604025176a9202cfbb4132be7e9e93adda48798d075c9b&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse3.explicit.bing.net%2Fth%2Fid%2FOIP.dkCyn12LuEF5tVEAHEytgwHaE3%3Fr%3D0%26pid%3DApi&f=1&ipt=ad4bb2a419921a25bf12980a8994b72177feedc735dd28613731473f269fee24&ipo=images',
    'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse3.mm.bing.net%2Fth%2Fid%2FOIP.u4_qxgqfmVS46Z6dQwT7PgHaHl%3Fr%3D0%26pid%3DApi&f=1&ipt=01e917ea4fc06bfd0e3dbfbe8afe8a611449391d08667d1eb67176cf18dc1b2b&ipo=images',
]
len(black_bear_imgs),len(grizzly_bear_imgs),len(teddy_bear_imgs)
# Out:
# (10, 10, 10)

# %%
bear_types = {
    'grizzly': grizzly_bear_imgs,
    'black'  : black_bear_imgs,
    'teddy'  : teddy_bear_imgs,
}
path = fastai.Path('bears')
if not path.exists():
    path.mkdir()
for (bear_type, bear_imgs) in bear_types.items():
    print(f'Downloading {len(bear_imgs)} images for {bear_type}')
    dest = (path/bear_type)
    dest.mkdir(exist_ok=True)
    for i, img_url in enumerate(bear_imgs):
        fastbook.download_url(img_url, dest/f'{bear_type}_{i}.jpg')
# Out:
# ...
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8192' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -819200.00% [8192/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
# ...

# %%
bears = fastai.DataBlock(
 blocks=(fastai.ImageBlock, fastai.CategoryBlock),
 get_items=fastai.get_image_files,
 splitter=fastai.RandomSplitter(valid_pct=0.2, seed=42),
 get_y=fastai.parent_label,
 item_tfms=fastai.Resize(128))

# %%
bears = bears.new(
 item_tfms=fastai.RandomResizedCrop(224, min_scale=0.5),
 batch_tfms=fastai.aug_transforms())
dls = bears.dataloaders(path, bs=10)

# %%
learn = fastai.cnn_learner(dls, fastai.resnet18, metrics=fastai.error_rate)
learn.fine_tune(1)
# Out:
# /usr/local/lib/python3.12/dist-packages/fastai/vision/learner.py:303: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
# ...

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
lbl_pred = widgets.Label()
out_pl = widgets.Output()
def on_click_classify(change):
 img = fastai.PILImage.create(btn_upload.data[-1])
 out_pl.clear_output()
 with out_pl: display(img.to_thumb(128,128))
 pred,pred_idx,probs = learn.predict(img)
 lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
btn_run.on_click(on_click_classify)

# %%
display(widgets.VBox([widgets.Label('Select your bear!'), btn_upload, btn_run, out_pl, lbl_pred]))
